# %%
pip install exa_py
# Out:
# Collecting exa_py
#   Downloading exa_py-1.7.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from exa_py) (2.32.2)
# Requirement already satisfied: typing-extensions in c:\users\admin\anaconda3\lib\site-packages (from exa_py) (4.11.0)
# Requirement already satisfied: openai>=1.10.0 in c:\users\admin\anaconda3\lib\site-packages (from exa_py) (1.48.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\admin\anaconda3\lib\site-packages (from openai>=1.10.0->exa_py) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->exa_py) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->exa_py) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->exa_py) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->exa_py) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.10.0->exa_py) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.10.0->exa_py) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.10.0->exa_py) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.10.0->exa_py) (2.23.4)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm>4->openai>=1.10.0->exa_py) (0.4.6)
# Downloading exa_py-1.7.1-py3-none-any.whl (10 kB)
# Installing collected packages: exa_py
# Successfully installed exa_py-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from exa_py import Exa
exa=Exa('c0ab5a55-f1bb-4b88-9eca-48ef52662923')

# %%
response = exa.search(
  'best pizza in Brooklyn',
  num_results=10,
  start_published_date='2023-05-01', 
  category='tweet', 
  use_autoprompt=True,
)

# %%
from exa_py import Exa

exa = Exa('c0ab5a55-f1bb-4b88-9eca-48ef52662923')

query = input('Search here: ')

response = exa.search(
  'Best Chicago cold brew',
  num_results=10,
)
print(response)
# Out:
# Search here:  cold brew
# Title: Kyoto Black - Kyoto Style Cold Brew Coffee
# URL: https://kyotostylecoffee.com/
# ID: https://kyotostylecoffee.com/
# Score: 0.1789800077676773
# Published Date: 2023-01-01T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Online Coffee Store | Best Coffee Roasters - Metropolis Coffee
# URL: https://www.metropoliscoffee.com/
# ID: https://www.metropoliscoffee.com/
# Score: 0.1775301992893219
# Published Date: 2022-09-06T00:00:00.000Z
# Author: Metropolis Coffee Company
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Black Fodder Coffee | Espresso Bar | Coffee Tea Catering | Chicago
# URL: https://blackfodder.co/
# ID: https://blackfodder.co/
# Score: 0.17648009955883026
# Published Date: 2023-01-01T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Home
# URL: https://coldbloodedcoffeeandroastery.com/
# ID: https://coldbloodedcoffeeandroastery.com/
# Score: 0.1756519079208374
# Published Date: 2018-04-30T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Chicago Coffee Roaster | Tugboat Coffee | United States
# URL: https://www.tugboatcoffee.com/
# ID: https://www.tugboatcoffee.com/
# Score: 0.1755651831626892
# Published Date: 2020-06-13T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Big Shoulders Coffee
# URL: https://www.bigshoulderscoffee.com/
# ID: https://www.bigshoulderscoffee.com/
# Score: 0.17518071830272675
# Published Date: 2014-02-03T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Perkolator
# URL: https://perkolatorcoffee.com/
# ID: https://perkolatorcoffee.com/
# Score: 0.174483522772789
# Published Date: 2023-01-03T00:00:00.000Z
# Author: Joseph Basilone
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: New for Spring: Smoothies & Refreshers
# URL: https://twobrotherscoffeeroasters.com/
# ID: https://twobrotherscoffeeroasters.com/
# Score: 0.1741730272769928
# Published Date: 2022-09-06T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Free Shipping* on Coffee Subscriptions
# URL: https://metriccoffee.com/
# ID: https://metriccoffee.com/
# Score: 0.1723288744688034
# Published Date: 2023-01-01T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: HOME | jackalopecoffee
# URL: https://www.jackalopecoffee.com/
# ID: https://www.jackalopecoffee.com/
# Score: 0.1719505935907364
# Published Date: 2016-01-01T00:00:00.000Z
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Autoprompt String: The best Chicago cold brew is
# Resolved Search Type: neural

# %%
from exa_py import Exa

exa = Exa('c0ab5a55-f1bb-4b88-9eca-48ef52662923')

query = input('Search here: ')

response = exa.search(
  query,
  num_results=5,
  type='keyword',
  include_domains=['https://www.tiktok.com'],
)

print(response)
# Out:
# Search here:  coffee
# Title: coffee
# URL: https://www.tiktok.com/tag/coffee
# ID: https://www.tiktok.com/tag/coffee
# Score: None
# Published Date: None
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Craft Coffee
# URL: https://www.tiktok.com/channel/craft-coffee
# ID: https://www.tiktok.com/channel/craft-coffee
# Score: None
# Published Date: None
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Coffee Drinks
# URL: https://www.tiktok.com/channel/coffee-drinks
# ID: https://www.tiktok.com/channel/coffee-drinks
# Score: None
# Published Date: None
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: Coffee Shop
# URL: https://www.tiktok.com/channel/coffee-shop
# ID: https://www.tiktok.com/channel/coffee-shop
# Score: None
# Published Date: None
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: My Coffee
# URL: https://www.tiktok.com/channel/my-coffee
# ID: https://www.tiktok.com/channel/my-coffee
# Score: None
# Published Date: None
# Author: None
# Image: None
# Extras None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
# Resolved Search Type: keyword

# %%
for result in response.results:
  print(f'Title: {result.title}')
  print(f'URL: {result.url}')
  print()
# Out:
# Title: coffee
# URL: https://www.tiktok.com/tag/coffee
#
# Title: Craft Coffee
# URL: https://www.tiktok.com/channel/craft-coffee
#
# Title: Coffee Drinks
# URL: https://www.tiktok.com/channel/coffee-drinks
#
# Title: Coffee Shop
# URL: https://www.tiktok.com/channel/coffee-shop
#
# Title: My Coffee
# URL: https://www.tiktok.com/channel/my-coffee
